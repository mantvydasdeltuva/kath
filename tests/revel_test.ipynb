# %%
import pandas as pd
import importlib
import os

# %%
back_end_path = '../app/back_end/'

gnomad_path = back_end_path + 'src/tools/revel/data/lovd_gnomad.csv'


data = pd.read_csv(gnomad_path)
data = data.convert_dtypes()
data.sort_values(by="hg38_gnomad_format", inplace=True)

display(data)
# Out:
#            id  transcriptid  effectid  position_c_start  \
# 0      822823          7329        70               632
# 1      822787          7329        70              8391
# 2      822843          7329        70              5608
# 3      822771          7329        70              8206
# 91     958489          7329        70              9418
# ...       ...           ...       ...               ...
# 15930    <NA>          <NA>      <NA>              <NA>
# 15931    <NA>          <NA>      <NA>              <NA>
# 15932    <NA>          <NA>      <NA>              <NA>
# 15933    <NA>          <NA>      <NA>              <NA>
# 15934    <NA>          <NA>      <NA>              <NA>
#
#        position_c_start_intron  position_c_end  position_c_end_intron  \
# 0                            0             632                      0
# 1                            0            8391                      0
# 2                            0            5608                      0
# 3                            0            8206                      0
# 91                           0            9418                      0
# ...                        ...             ...                    ...
# 15930                     <NA>            <NA>                   <NA>
# 15931                     <NA>            <NA>                   <NA>
# 15932                     <NA>            <NA>                   <NA>
# 15933                     <NA>            <NA>                   <NA>
# 15934                     <NA>            <NA>                   <NA>
#
#       VariantOnTranscript/DNA VariantOnTranscript/RNA  \
# 0                    c.632G>A                   r.(?)
# 1                   c.8391del                   r.(?)
# 2                   c.5608C>T                   r.(?)
# 3                   c.8206G>C                   r.(?)
# 91                  c.9418C>T                   r.(?)
# ...                       ...                     ...
# 15930                    <NA>                    <NA>
# 15931                    <NA>                    <NA>
# 15932                    <NA>                    <NA>
# 15933                    <NA>                    <NA>
# 15934                    <NA>                    <NA>
#
#       VariantOnTranscript/Protein VariantOnTranscript/Exon  \
# 0                   p.(Cys211Tyr)                     <NA>
# 1             p.(Gly2799Valfs*31)                     <NA>
# 2                  p.(Arg1870Trp)                     <NA>
# 3                  p.(Ala2736Pro)                     <NA>
# 91                 p.(Gln3140Ter)                     <NA>
# ...                           ...                      ...
# 15930                        <NA>                     <NA>
# 15931                        <NA>                     <NA>
# 15932                        <NA>                     <NA>
# 15933                        <NA>                     <NA>
# 15934                        <NA>                     <NA>
#
#       VariantOnGenome/DNA VariantOnGenome/DNA/hg38 hg38_gnomad_format  \
# 0          g.216052273del           g.215878931del    6-215878931-del
# 1          g.216052410C>T           g.215879068C>T    6-215879068-C-T
# 2          g.216246607G>A           g.216073265G>A    6-216073265-G-A
# 3          g.216500979C>T           g.216327637C>T    6-216327637-C-T
# 91          g.64430509G>A            g.63720613G>A     6-63720613-G-A
# ...                   ...                      ...                ...
# 15930                <NA>                     <NA>               <NA>
# 15931                <NA>                     <NA>               <NA>
# 15932                <NA>                     <NA>               <NA>
# 15933                <NA>                     <NA>               <NA>
# 15934                <NA>                     <NA>               <NA>
#
#        Popmax_gnomad  Popmax population_gnomad  Homozygote Count_gnomad  \
# 0               <NA>                      <NA>                     <NA>
# 1               <NA>                      <NA>                     <NA>
# 2               <NA>                      <NA>                     <NA>
# 3               <NA>                      <NA>                     <NA>
# 91              <NA>                      <NA>                     <NA>
# ...              ...                       ...                      ...
# 15930       0.000031  African/African American                        0
# 15931            0.0                      <NA>                        0
# 15932        0.00007          Admixed American                        0
# 15933        0.00006               South Asian                        0
# 15934       0.000012               South Asian                        0
#
#        Allele Frequency_gnomad variant_id_gnomad
# 0                         <NA>              <NA>
# 1                         <NA>              <NA>
# 2                         <NA>              <NA>
# 3                         <NA>              <NA>
# 91                        <NA>              <NA>
# ...                        ...               ...
# 15930                 0.000001    6-65495479-G-A
# 15931                      0.0    6-65495479-G-T
# 15932                 0.000003    6-65495482-A-G
# 15933                 0.000004    6-65495484-T-G
# 15934                 0.000001    6-65495485-T-C
#
# [16415 rows x 19 columns]

# %%
import sys
import os

sys.path.append(os.path.abspath('../app/back_end/src/tools/revel/'))
import revel

new_gene_data = revel.main_revel_pipeline(gnomad_path)
# Out:
# Data store directory not provided. Using default folder.
# REVEL data already exists at /mnt/c/Users/Kajus/PycharmProjects/kath-1/app/back_end/src/tools/revel/data/revel_with_transcript_ids
# REVEL DB already exists at /mnt/c/Users/Kajus/PycharmProjects/kath-1/app/back_end/src/tools/revel/data/revel_with_transcript_ids.db
# Assigning REVEL scores...
#  Errors will be logged.
# Assigning REVEL scores: |████████████████████████████████████████████████--| 97.2% Complete (15950/16415)
#               id  transcriptid  effectid  position_c_start  \
# 0       822823.0        7329.0      70.0             632.0
# 1       822787.0        7329.0      70.0            8391.0
# 2       822843.0        7329.0      70.0            5608.0
# 3       822771.0        7329.0      70.0            8206.0
# 4            NaN           NaN       NaN               NaN
# ...          ...           ...       ...               ...
# 16410   959064.0        7329.0      50.0               0.0
# 16411   985494.0        7329.0      70.0            2137.0
# 16412   986425.0        7329.0      90.0            4361.0
# 16413   987322.0        7329.0      90.0            9299.0
# 16414  1014230.0        7329.0      50.0            8255.0
#
#        position_c_start_intron  position_c_end  position_c_end_intron  \
# 0                          0.0           632.0                    0.0
# 1                          0.0          8391.0                    0.0
# 2                          0.0          5608.0                    0.0
# 3                          0.0          8206.0                    0.0
# 4                          NaN             NaN                    NaN
# ...                        ...             ...                    ...
# 16410                      0.0             0.0                    0.0
# 16411                  20590.0          3444.0               -29847.0
# 16412                      0.0          4362.0                    0.0
# 16413                      0.0          9302.0                    0.0
# 16414                      0.0          8260.0                    0.0
#
#           VariantOnTranscript/DNA VariantOnTranscript/RNA  \
# 0                        c.632G>A                   r.(?)
# 1                       c.8391del                   r.(?)
# 2                       c.5608C>T                   r.(?)
# 3                       c.8206G>C                   r.(?)
# 4                             NaN                     NaN
# ...                           ...                     ...
# 16410      c.-538_862+10652{1}inv                     r.?
# 16411  c.2137+20590_3444-29847del                     r.?
# 16412         c.4361_4362delinsAG                   r.(?)
# 16413              c.9299_9302del                   r.(?)
# 16414              c.8255_8260del                   r.(?)
#
#         VariantOnTranscript/Protein VariantOnTranscript/Exon  \
# 0                     p.(Cys211Tyr)                      NaN
# 1               p.(Gly2799Valfs*31)                      NaN
# 2                    p.(Arg1870Trp)                      NaN
# 3                    p.(Ala2736Pro)                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 16410                           p.?                    _1_5i
# 16411          p.(Val713AspfsTer14)                      NaN
# 16412                p.(Ser1454Ter)                       26
# 16413         p.(Thr3100LysfsTer26)                      NaN
# 16414  p.(Leu2752_Asn2754delinsTyr)                      NaN
#
#                VariantOnGenome/DNA     VariantOnGenome/DNA/hg38  \
# 0                   g.216052273del               g.215878931del
# 1                   g.216052410C>T               g.215879068C>T
# 2                   g.216246607G>A               g.216073265G>A
# 3                   g.216500979C>T               g.216327637C>T
# 4                              NaN                          NaN
# ...                            ...                          ...
# 16410       g.66189835_67841160inv       g.65479942_67131267inv
# 16411       g.65365985_65746917del       g.64656092_65037024del
# 16412  g.65301398_65301399delinsCT  g.64591505_64591506delinsCT
# 16413       g.64430626_64430629del       g.63720730_63720733del
# 16414       g.64431667_64431672del                          NaN
#
#       hg38_gnomad_format  Popmax_gnomad Popmax population_gnomad  \
# 0        6-215878931-del            NaN                      NaN
# 1        6-215879068-C-T            NaN                      NaN
# 2        6-216073265-G-A            NaN                      NaN
# 3        6-216327637-C-T            NaN                      NaN
# 4                    NaN            0.0                      NaN
# ...                  ...            ...                      ...
# 16410                  ?            NaN                      NaN
# 16411                  ?            NaN                      NaN
# 16412                  ?            NaN                      NaN
# 16413                  ?            NaN                      NaN
# 16414                  ?            NaN                      NaN
#
#        Homozygote Count_gnomad  Allele Frequency_gnomad variant_id_gnomad  \
# 0                          NaN                      NaN               NaN
# 1                          NaN                      NaN               NaN
# 2                          NaN                      NaN               NaN
# 3                          NaN                      NaN               NaN
# 4                          0.0                      0.0    6-63720525-A-C
# ...                        ...                      ...               ...
# 16410                      NaN                      NaN               NaN
# 16411                      NaN                      NaN               NaN
# 16412                      NaN                      NaN               NaN
# 16413                      NaN                      NaN               NaN
# 16414                      NaN                      NaN               NaN
#
#       REVEL
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
# ...     ...
# 16410  <NA>
# 16411  <NA>
# 16412  <NA>
# 16413  <NA>
# 16414  <NA>
#
# [16415 rows x 20 columns]

# %%
## ignore Revel NA
new_gene_data = new_gene_data[new_gene_data['REVEL'] != 'NA']

new_gene_data.sort_values(by="REVEL", inplace=True)

display(new_gene_data)
# Out:
#               id  transcriptid  effectid  position_c_start  \
# 3266    235663.0        7329.0      33.0            7182.0
# 3567    477502.0        7329.0      10.0            6977.0
# 3569    529320.0        7329.0      10.0            6977.0
# 3565    342334.0        7329.0      10.0            6977.0
# 3568    529319.0        7329.0      10.0            6977.0
# ...          ...           ...       ...               ...
# 16410   959064.0        7329.0      50.0               0.0
# 16411   985494.0        7329.0      70.0            2137.0
# 16412   986425.0        7329.0      90.0            4361.0
# 16413   987322.0        7329.0      90.0            9299.0
# 16414  1014230.0        7329.0      50.0            8255.0
#
#        position_c_start_intron  position_c_end  position_c_end_intron  \
# 3266                       0.0          7182.0                    0.0
# 3567                       0.0          6977.0                    0.0
# 3569                       0.0          6977.0                    0.0
# 3565                       0.0          6977.0                    0.0
# 3568                       0.0          6977.0                    0.0
# ...                        ...             ...                    ...
# 16410                      0.0             0.0                    0.0
# 16411                  20590.0          3444.0               -29847.0
# 16412                      0.0          4362.0                    0.0
# 16413                      0.0          9302.0                    0.0
# 16414                      0.0          8260.0                    0.0
#
#           VariantOnTranscript/DNA VariantOnTranscript/RNA  \
# 3266                    c.7182T>C                   r.(?)
# 3567                    c.6977G>A                   r.(?)
# 3569                    c.6977G>A                   r.(?)
# 3565                    c.6977G>A                   r.(?)
# 3568                    c.6977G>A                   r.(?)
# ...                           ...                     ...
# 16410      c.-538_862+10652{1}inv                     r.?
# 16411  c.2137+20590_3444-29847del                     r.?
# 16412         c.4361_4362delinsAG                   r.(?)
# 16413              c.9299_9302del                   r.(?)
# 16414              c.8255_8260del                   r.(?)
#
#         VariantOnTranscript/Protein VariantOnTranscript/Exon  \
# 3266                          p.(=)                       36
# 3567                 p.(Arg2326Gln)                      NaN
# 3569                 p.(Arg2326Gln)                      NaN
# 3565                 p.(Arg2326Gln)                      NaN
# 3568                 p.(Arg2326Gln)                      NaN
# ...                             ...                      ...
# 16410                           p.?                    _1_5i
# 16411          p.(Val713AspfsTer14)                      NaN
# 16412                p.(Ser1454Ter)                       26
# 16413         p.(Thr3100LysfsTer26)                      NaN
# 16414  p.(Leu2752_Asn2754delinsTyr)                      NaN
#
#                VariantOnGenome/DNA     VariantOnGenome/DNA/hg38  \
# 3266                 g.64574125A>G                g.63864232A>G
# 3567                 g.64694354C>T                g.63984461C>T
# 3569                 g.64694354C>T                g.63984461C>T
# 3565                 g.64694354C>T                g.63984461C>T
# 3568                 g.64694354C>T                g.63984461C>T
# ...                            ...                          ...
# 16410       g.66189835_67841160inv       g.65479942_67131267inv
# 16411       g.65365985_65746917del       g.64656092_65037024del
# 16412  g.65301398_65301399delinsCT  g.64591505_64591506delinsCT
# 16413       g.64430626_64430629del       g.63720730_63720733del
# 16414       g.64431667_64431672del                          NaN
#
#       hg38_gnomad_format  Popmax_gnomad Popmax population_gnomad  \
# 3266      6-63864232-A-G       0.000002   European (non-Finnish)
# 3567      6-63984461-C-T       0.585526                    Amish
# 3569      6-63984461-C-T       0.585526                    Amish
# 3565      6-63984461-C-T       0.585526                    Amish
# 3568      6-63984461-C-T       0.585526                    Amish
# ...                  ...            ...                      ...
# 16410                  ?            NaN                      NaN
# 16411                  ?            NaN                      NaN
# 16412                  ?            NaN                      NaN
# 16413                  ?            NaN                      NaN
# 16414                  ?            NaN                      NaN
#
#        Homozygote Count_gnomad  Allele Frequency_gnomad variant_id_gnomad  \
# 3266                       0.0                 0.000001    6-63864232-A-G
# 3567                   99961.0                 0.357163    6-63984461-C-T
# 3569                   99961.0                 0.357163    6-63984461-C-T
# 3565                   99961.0                 0.357163    6-63984461-C-T
# 3568                   99961.0                 0.357163    6-63984461-C-T
# ...                        ...                      ...               ...
# 16410                      NaN                      NaN               NaN
# 16411                      NaN                      NaN               NaN
# 16412                      NaN                      NaN               NaN
# 16413                      NaN                      NaN               NaN
# 16414                      NaN                      NaN               NaN
#
#        REVEL
# 3266   0.012
# 3567   0.013
# 3569   0.013
# 3565   0.013
# 3568   0.013
# ...      ...
# 16410   <NA>
# 16411   <NA>
# 16412   <NA>
# 16413   <NA>
# 16414   <NA>
#
# [16415 rows x 20 columns]

# %%
import os
import requests
import pandas as pd

workspace_dir = '/mnt/c/Users/Kajus/PycharmProjects/kath-1/app/back_end/workspace/test-uuid'
input_file = os.path.join(workspace_dir, 'input.csv')
output_file = os.path.join(workspace_dir, 'output.csv')

url = "http://127.0.0.1:8080/workspace/apply/revel/output.csv"
headers = {
    "uuid": "test-uuid",
    "sid": "test-session-id"
}
params = {
    "override": "true",
    "applyTo": "input.csv"
}

response = requests.get(url, headers=headers, params=params)
print(response)

# Verify output file
if os.path.exists(output_file):
    result_data = pd.read_csv(output_file)
    print(result_data)
else:
    print("Output file not found")
# Out:
# <Response [404]>
# Output file not found
